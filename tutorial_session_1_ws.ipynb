# %% [markdown]
# <h2 style="text-align: center; font-family: Calibri, sans-serif; font-size: 36px;">
#   Tutorial Session 1
# </h2>
#
# ---

# %% [markdown]
# ## Financial Decision Making
#
# ---

# %% [markdown]
# ### Question 1.1
#
# Consider an offer to trade 5 troy ounces (oz) of rhodium for 150 oz of palladium. Current competitive market prices are approximately £950 per oz for palladium and £5000 per oz for rhodium.
#
# * Based on current market prices, does this trade represent a positive net value? Explain using the Law of One Price or valuation principles.
#
# * Under what specific market price conditions (deviation from current prices) might this trade become unappealing?
#
# * What action might you consider if you strongly anticipated palladium prices falling to £900 per oz within the next day, assuming you could execute related transactions instantly?
#
# * How does your personal belief about the "fairness" of the current rhodium or palladium prices affect the decision to accept the trade based solely on market values?
#
# ---

# %% [markdown]
# ### Question 1.1: Solution
#
# **Net value today**
# - Give: 5 oz Rh @ £5 000/oz = £25 000
# - Receive: 150 oz Pd @ £950/oz = £142 500
# - Net gain = £142 500 – £25 000 = £117 500 → positive value (Law of One Price arbitrage).
#
# **When it becomes unappealing**
# - Break-even condition:
# $$
#      150\,P_{Pd}=5\,P_{Rh}
#      \;\Longrightarrow\;
#      P_{Pd}=\frac{P_{Rh}}{30}.
#      $$
# - At today’s £5 000/oz Rh, break-even Pd = £5 000/30 ≈ £166.67/oz
# - If $P_{Pd}<P_{Rh}/30$ (or $P_{Rh}<30\,P_{Pd}$), the deal flips negative.
#
# **Role of “fairness” beliefs**
# - Irrelevant for pure arbitrage: decision relies solely on market prices.
# - Personal fair-value views don’t alter the immediate positive net value under current quotes.
#
# ---

# %% [markdown]
# ### Question 1.2
#
# * Suppose the risk-free interest rate ($r$) is 5%.
#     * What are the discount factors for:
#         * one year?
#         * three years?
#         * six years?
#     * What are the interest rate factors (future value factors) for:
#         * two years?
#         * four years?
#         * seven years?
#
# ---

# %% [markdown]
# ### Question 1.2: Solution
#
# **Discount factors** at $r=5\%$: $\quad DF_t = \frac1{(1.05)^t}$
# - $DF_1 = \dfrac1{1.05} \approx 0.95238$
# - $DF_3 = \dfrac1{1.05^3} \approx 0.86384$
# - $DF_6 = \dfrac1{1.05^6} \approx 0.74622$
#
# **Future‐value factors** at $r=5\%$: $\quad IF_t = (1.05)^t$
# - $IF_2 = (1.05)^2 = 1.1025$
# - $IF_4 = (1.05)^4 \approx 1.21551$
# - $IF_7 = (1.05)^7 \approx 1.40710$
#
# ---

# %% [markdown]
# ### Question 1.3
#
# Consider a risk-free security issued by the Beta Institute that promises to pay investors the following cash flows:
#
#  * $50 exactly one year from today
#
#  * $70 exactly two years from today
#
#  * $120 exactly three years from today
#
# Suppose the current annualized risk-free interest rates for these maturities are as follows:
#
#  * One-year risk-free rate ($r_1$): 4.0%
#  * Two-year risk-free rate ($r_2$): 4.5%
#  * Three-year risk-free rate ($r_3$): 5.0%
#
# **What is the theoretical no-arbitrage price of this security today? Describe the calculation required.**
#
# **If this security is currently trading in the market for a price of $215, clearly describe the sequence of transactions you would need to undertake today and in the future to lock in a risk-free arbitrage profit. Specify the amount of profit you would realize today.**
#
# ---

# %% [markdown]
# ### Question 1.3: Solution
#
# **Theoretical no‐arbitrage price**
#
# $P = \frac{50}{1.04}   + \frac{70}{1.045^2} + \frac{120}{1.05^3} \approx 48.08 + 64.11 + 103.68 = 215.87 $
#
# **Arbitrage if market price = $215**
#
# Raise $215.87 today by borrowing:
#    - $48.08 due in 1 year
#    - $64.11 due in 2 years
#    - $103.68 due in 3 years
#
# Buy the security for $215: $\quad 215.87 - 215 = \$0.87$
#
# Future cash flows of $50, $70, $120 repay exactly the three loans—no other net cash flows.
#
# Immediate profit = $0.87 today.
#
# ---

# %% [markdown]
# ## Time, Money, and Interest Rates
#
# ---

# %% [markdown]
# ### Question 2.1
# For each of the following scenarios, compute the present value:
#
# | Present Value | Years | Interest Rate | Future Value  |
# |---------------|-------|---------------|---------------|
# |               | 7     | 6\%           | \$14,235      |
# |               | 11    | 12\%          | \$52,148      |
# |               | 15    | 9\%           | \$812,730     |
# |               | 22    | 14\%          | \$614,390     |
#
# ---

# %% [markdown]
# ### Question 2.1: Solution
#
# $PV = \frac{FV}{(1+i)^n}$
#
# $PV = \frac{14\,235}{1.06^7}\approx9\,467.09$
#
# $PV = \frac{52\,148}{1.12^{11}}\approx14\,991.30$
#
# $PV = \frac{812\,730}{1.09^{15}}\approx223\,125.30$
#
# $PV = \frac{614\,390}{1.14^{22}}\approx34\,398.33$
#
#
# ---

# %% [markdown]
# ### Question 2.2
# * The Infinity Wealth Management Company is trying to sell you an investment policy that will pay you and your heirs \$18,000 per year forever.
#     - If the required return on this investment is 6.3\%, how much will you pay for the policy?
#     - If you are told that the policy costs $350,000. At what interest rate would this be a fair deal?
#
# ---

# %% [markdown]
# ### Question 2.2: Solution
#
# * **Price for a 6.3% required return**
#   $$PV = \frac{C}{r} = \frac{18\,000}{0.063} = 285\,714.29$$
#
# * **Implied rate if cost = \$350,000**
#   $$r = \frac{C}{PV} = \frac{18\,000}{350\,000} = 0.05142857 \approx 5.14\%$$
#
#
# ---

# %% [markdown]
# ### Question 2.3
# Investment A offers to pay you $\$4,500$ per year for 12 years, whereas Investment B offers to pay you $\$7,200$ per year for 6 years. Which investment would you choose under the following interest rate scenarios:
#
# - 6 percent
# - 25 percent
# ---

# %% [markdown]
# ### Question 2.3: Solution
#
# **At $i=6\%$**
# $$
# PV_A = 4500\;\frac{1 - 1.06^{-12}}{0.06}\approx 37\,725,\quad
# PV_B = 7200\;\frac{1 - 1.06^{-6}}{0.06}\approx 35\,400 \quad \implies \quad \text{Choose A}$$
#
# **At $i=25\%$**
# $$
# PV_A = 4500\;\frac{1 - 1.25^{-12}}{0.25}\approx 16\,764,\quad
# PV_B = 7200\;\frac{1 - 1.25^{-6}}{0.25}\approx 21\,250 \quad \implies \quad \text{Choose B}$$
#
# ---

# %% [markdown]
# ### Question 2.4
#
# * You want to buy a house in 10 years and estimate a house of your liking will cost $200,000.
#     * Assume that you are able to earn a return of 8% on these savings.
#     * What is the amount you need to save each year?
#
# ---

# %% [markdown]
# ### Question 2.4: Solution
#
# $$x\;\frac{(1.08)^{10}-1}{0.08} =200\,000 \quad \Rightarrow \quad x =\frac{200\,000\times0.08}{(1.08)^{10}-1} \approx\$13\,805$$
#
# ---

# %% [markdown]
# ### Question 2.5
#
# * Suppose we have a \$250,000 commercial mortgage with a 12\% interest rate to be paid monthly over 15 years.
#
#     * What should the monthly payments be?
#
#     * Now, suppose that the borrower intends to fully pay the remaining balance on the loan after the 60th monthly payment. What will be the required amount for this payment?
#
#     * If the borrower intends to fully amortize the loan at the end of 15th year but wants to make balloon payments of $50,000 at the end of 5th, and 10th years, what should the monthly payments be?
#
#     * Suppose that the borrower firm wants to explore a 10-year mortgage with two equal balloon payments at the end of 3rd and 7th years.
#         * Additionally, the financial manager of the firm makes it clear that the maximum amount for monthly payments should be $3,250.
#         * What is the minimum amount of the balloon payments needed for fully amortizing the loan at the end of 10th year?
#
# ---

# %% [markdown]
# ### Question 2.5: Solution
#
# Let $i = 0.12/12 = 0.01$, $N_{15} = 15\times12 = 180$, $N_{10} = 10\times12 = 120$.
#
# **Level monthly payment on 15-year loan**
# $$
# R = \frac{P\,i}{1 - (1+i)^{-N_{15}}}
#   = \frac{250\,000 \times 0.01}{1 - 1.01^{-180}}
#   \approx 3000.42.
# $$
#
# **Outstanding balance after 60 payments**
# $$
# B_{60}
# = R\,\frac{1 - (1+i)^{-(N_{15}-60)}}{i}
# = 3000.42 \;\frac{1 - 1.01^{-120}}{0.01}
# \approx 209130.85.
# $$
#
# **Monthly payment with \$50 000 balloons at $t=60$ and $t=120$**
# $$250\,000 = R\,\frac{1 - (1+i)^{-N_{15}}}{i} + 50\,000\bigl(1.01^{-60} + 1.01^{-120}\bigr) \quad \Rightarrow \quad R = \frac{250\,000 - 50\,000\,(1.01^{-60} + 1.01^{-120})} {\bigl(1 - 1.01^{-180}\bigr)/0.01} \approx 2488.28 $$
#
# **Minimum equal balloons $B$ at $t=36$ and $t=84$ for a 10-year loan with $R=3250$**
# $$ 250\,000 = 3250\,\frac{1 - (1+i)^{-N_{10}}}{i} + B\bigl(1.01^{-36} + 1.01^{-84}\bigr) \quad \Rightarrow \quad B = \frac{250\,000 - 3250\,\bigl(1 - 1.01^{-120}\bigr)/0.01} {1.01^{-36} + 1.01^{-84}} \approx 20728.07 $$
#
# ---

# %% [markdown]
# ### Question 2.6
# * You have just purchased a new house. To finance the purchase, you've arranged for a 30-year mortgage for 80 percent of the $\$600,000$ purchase price. The monthly payment on this loan will be $\$2,800$.
#   - What is the APR on this loan?
#   - The EAR?
#
# ---

# %% [markdown]
# ### Question 2.6: Solution
#
# $$480000 = 2800\frac{1 - (1+i)^{-360}}{i} \;\Longrightarrow\; i \approx 0.00479$$
# $$APR = 12i \approx 5.75\%, \quad EAR = (1+i)^{12}-1 \approx 5.90\%$$
#
# ---

# %% [markdown]
# ### Question 2.7
# Alex Roberts owns a chain of artisanal bakery cafes in downtown San Francisco. He charges his customers an annual membership fee of $\$350$ and currently has a loyal customer base of 600 members. Alex plans to raise the annual fee by 5% every year and expects his membership to grow at a constant rate of 4% per year over the next five years. His business incurs operating expenses of $\$100,000$ per year, and these costs are expected to increase at the inflation rate of 3% annually. At the end of five years, Alex intends to invest $\$600,000$ in a new boutique hotel venture and then close his cafes to retire and travel the world.
#
# After spending $\$600,000$ on his new venture, the remaining savings are invested in an account that earns an 8% annual return. Alex plans to fund his world travels over a 20-year retirement, withdrawing an equal amount at the beginning of each year, and depleting the account completely by the end of the 20 years.
#
# What is the annual amount that Alex can spend during his 20-year retirement (in today’s dollars), and what is the corresponding nominal amount of his final withdrawal, assuming the annual withdrawals are indexed to inflation?
#
# ---

# %% [markdown]
# ### Question 2.7: Solution
#
# **Surplus during café years and future value at end-year 5 (nominal $)**
#
# | Year | surplus | compounding factor $(1.08)^{5-t}$ | FV at end-5 |
# |-----:|--------:|-----------------------------------:|------------:|
# | 1 | 110 000.00 | 1.36049 | 149 653.79 |
# | 2 | 126 320.00 | 1.25971 | 159 126.97 |
# | 3 | 144 327.44 | 1.16640 | 168 343.53 |
# | 4 | 164 183.14 | 1.08000 | 177 317.79 |
# | 5 | 186 062.90 | 1.00000 | 186 062.90 |
# | **total FV (end-5)** | | | **840 504.98** |
#
# **Retirement fund at $t = 5$**
#
# Nominal fund after hotel investment: $\quad \text{Fund}_{\text{nom},5} = 840\,504.98 - 600\,000 = 240\,504.98$
#
# Converted to today’s purchasing power $(\text{inflation } 3\% \text{ for 5 years})$  $\quad \text{Fund}_{\text{real}} = \frac{240\,504.98}{1.03^{5}} = 207\,461.71$
#
# **Real withdrawal amount (annuity-due, 20 years)**
#
# Real return: $\quad r = \frac{1.08}{1.03} - 1 = 0.0485436893$
#
# Annuity-due factor: $\quad A = \left(\frac{1 - (1+r)^{-20}}{r}\right)(1+r) = 13.23004476$
#
# Equal annual withdrawal in today’s dollars: $\quad W_{\text{real}} = \frac{207\,461.71}{13.23004476} = 15\,681.10$
#
# **Nominal withdrawals (indexed to 3 % inflation)**
#
# First withdrawal (start of year 6): $\quad W_0 = 15\,681.10 \times 1.03^{5} = 18\,178.70$
#
# Final (20th) withdrawal (start of year 25): $\quad W_{19} = 18\,178.70 \times 1.03^{19} = 31\,876.46$
#
# Alex can spend \$15 681.10 per year in today’s dollars; the nominal value of his last withdrawal will be \$31 876.46.
#
# ---

# %% [markdown]
# ## Investment Decison Rules
#
# ---

# %% [markdown]
# ### Question 3.1
# *   Mechano Inc. is considering a major factory expansion. This expansion is projected to generate additional net cash inflows of $\$310,000$ for the firm during the first year after completion. These cash flows are expected to grow steadily at a rate of **5 percent per year indefinitely**. The expansion requires an upfront investment of $3,800,000.
#     *   If Mechano Inc. requires a return of **14 percent** on such capital projects, should the factory expansion be undertaken? (Calculate the NPV).
#     *   Mechano Inc.'s management is concerned about the long-term growth forecast. At what constant perpetual growth rate would this expansion project just break even (NPV = 0), assuming the company still requires a **14 percent** return on investment?
#
# ---

# %% [markdown]
# ### Question 3.1: Solution
# NPV with 5 % perpetual growth
#
# $$\text{PV} = \frac{310\,000}{0.14-0.05}=3\,444\,444.44 \quad \Rightarrow \quad \text{NPV} = 3\,444\,444.44 - 3\,800\,000 = -355\,555.56$$
#
# The expansion should not be undertaken (negative NPV of –\$355 555.56).
#
# Break-even perpetual growth rate $g^*$
#
# $$
# \frac{310\,000}{0.14-g^*}=3\,800\,000 \;\;\Longrightarrow\;\;
# g^* = 0.14 - \frac{310\,000}{3\,800\,000}=0.0584
# $$
#
# The project’s NPV is zero when the cash-flow growth rate is approximately 5.84 % per year.
#
#
# ---

# %% [markdown]
# ### Question 3.2
#
# *   A real estate development firm is choosing between two mutually exclusive downtown revitalization projects. Both require the same initial investment of **\$15 million**.
#     *   Project **High Rise (HR)** will generate net rental income of **\$2.5 million** per year (starting at the end of the first year) in perpetuity.
#     *   Project **Mixed Use (MU)** will generate **\$1.8 million** at the end of the first year, and this income stream is expected to grow at **3%** per year indefinitely after that.
#     *   Which project has the higher IRR?
#     *   Which project has the higher NPV when the firm's cost of capital is **8%**?
#     *   In this situation, for what range of the cost of capital would choosing the project with the higher IRR lead to the correct decision (i.e., selecting the project with the higher NPV)?
#
# ---

# %% [markdown]
# ### Question 3.2: Solution
# Project IRRs
#
# $$IRR_{HR}=\frac{2.5}{15}=0.1667=16.67\%,\qquad
#   IRR_{MU}=0.03+\frac{1.8}{15}=0.1500=15.00\%.$$
#
# NPVs when the cost of capital is 8 %
#
# $$NPV_{HR}=\frac{2.5}{0.08}-15=16.25\text{ million},\qquad
#   NPV_{MU}=\frac{1.8}{0.08-0.03}-15=21.00\text{ million}.$$
#
# Incremental (crossover) IRR
#
# $$IRR_{\Delta}= \frac{2.5\,(0.03)}{2.5-1.8}=0.1071=10.71\%.$$
#
# Decision rule range
#
# * If $k<10.71\%$, $NPV_{MU}>NPV_{HR}$, so MU is correct even though HR has the higher IRR.
# * If $k>10.71\%$, $NPV_{HR}>NPV_{MU}$, and choosing HR (the higher-IRR project) is correct.
#
# Thus the IRR rule gives the right choice only when the firm’s cost of capital exceeds 10.71 %.
#
# ---

# %% [markdown]
# ### Question 3.3
#
# *   Your renewable energy company is considering developing a new geothermal power plant. The plant construction and setup will cost **\$250 million** immediately (Year 0). Once operational, the plant is expected to generate **\$35 million** in net cash flow per year for the next **12 years**. After 12 years, the plant will require ongoing monitoring and environmental compliance activities. These are expected to cost **\$2.5 million per year** in perpetuity, starting in Year 13.
#     *   What does the IRR rule indicate about whether you should accept this opportunity?
#     *   If the cost of capital for this project is **8.5%**, what does the NPV rule say about accepting the project?
#
# ---

# %% [markdown]
# ### Question 3.3: Solution
#
# Cash-flow pattern (in \$ millions)
#
# t = 0 : –250
# t = 1-12 : +35 each year
# t ≥ 13 : –2.5 each year
#
# The sequence – + – has two sign changes, so up to two IRRs are possible.
#
# $$0=-250+\frac{35\,[1-(1+r)^{-12}]}{r}-\frac{2.5\,(1+r)^{-12}}{r}.$$
#
# $$r_1 = 0.01597 \;(\,1.60\%\,),\qquad
#   r_2 = 0.08126 \;(\,8.13\%\ ).$$
#
# Because more than one IRR exists, the IRR rule is ambiguous.
#
# **NPV at the 8.50 % cost of capital**
#
# Present value of years 1-12 inflows: $\quad \frac{35\,[1-(1.085)^{-12}]}{0.085}=257.06$
#
# Present value of the perpetual \$2.5 outflow (starting year 13): $\quad \frac{2.5}{0.085}\,(1.085)^{-12}=11.05$
#
# $$NPV = -250 + 257.06 - 11.05 = -3.99\text{ million}$$
#
# **Decision: NPV is negative, so the project should be rejected.**
#
# ---

# %% [markdown]
# ### Question 3.4
#
# *   Your company typically spends **\$750,000 per year** on routine IT system upgrades and software licensing renewals. Due to budget constraints, the firm is considering skipping these expenditures for the next **three years** (Years 1, 2, and 3). If it does so, it anticipates a major system failure requiring replacement and data recovery costing **\$2.8 million** at the end of Year 4.
#     *   What is the IRR associated with the decision to forgo the IT upgrades?
#     *   Does the standard IRR decision rule work reliably for this specific decision? Why or why not?
#     *   For what range of costs of capital would forgoing the upgrades appear to be a financially beneficial decision (i.e., have a positive NPV)?
#
# ---

# %% [markdown]
# ### Question 3.4: Solution
#
# - IRR: $r \approx 11.3\%$ solves
#   $$0=\frac{750}{1+r}+\frac{750}{(1+r)^2}+\frac{750}{(1+r)^3}-\frac{2.8\times10^{6}}{(1+r)^4}$$
#
# - Does the usual IRR rule work?
#
#   Cash-flows are $+\!+\!+\!-$ (“financing-type”), so NPV increases with the discount rate $k$.
#
#   Accept when $k>r$; the standard “accept if $r>k$” rule is inverted.
#
# - Cost-of-capital range for positive NPV:
#
#   $\text{NPV}>0 \;\Longleftrightarrow\; k>11.3\%$
#
# ---

# %% [markdown]
# ### Question 3.5
#
# *   "App Wizards Inc." has designed a new productivity app. They can launch the app either with a basic feature set or as a premium version with enhanced capabilities, but launching both is not feasible. Consider the following estimated cash flows for these mutually exclusive options. Assume the appropriate discount rate for both projects is **12 percent**.
#
#     | Year | Basic App CF (\$k) | Premium App CF (\$k) |
#     | :----: | -----------------: | -------------------: |
#     | 0    | -500             | -1,200             |
#     | 1    | 350               | 800                 |
#     | 2    | 250               | 600                 |
#     | 3    | 100               | 300                 |
#
# *   Based *only* on the Payback Period rule, which app version should be launched?
# *   Based on the NPV rule, which app version should be chosen?
# *   Based *only* on the IRR rule, which app version should be chosen?
# *   Using the Incremental IRR method, which app version should be chosen?
#
# ---

# %% [markdown]
# ### Question 3.5: Solution
#
# - Payback Period: $\quad \text{Basic}:\;1 + \frac{150}{350}\approx1.6\text{ yr}<\text{Premium}:1 + \frac{400}{800}\approx1.67\text{ yr}$
#
#   **Choose Basic** (shorter payback).
#
# - NPV at k=12\%: $\quad \text{NPV}_{\text{Basic}}=\$83\text{k},\quad\text{NPV}_{\text{Premium}}=\$206\text{k}$
#
#   **Choose Premium** (higher NPV).
#
# - Standalone IRR: $\quad \text{IRR}_{\text{Basic}}\approx23.56\%,\quad\text{IRR}_{\text{Premium}}\approx23.53\%$
#
#   **Choose Basic** (slightly higher IRR).
#
# - Incremental IRR (Premium − Basic): $\quad$ Incremental CFs: $(-700,\;450,\;350,\;200) \quad \text{give} \quad \text{IRR}_{\text{inc}}\approx23.5\%>k=12\%$
#
#   **Choose Premium** (incremental return exceeds the hurdle rate).
#
# ---

# %% [markdown]
# ### Question 3.6
#
# *   Catalyst Marketing, a digital agency, has a daily budget of $1,200 to allocate across different online advertising campaigns for a client. Each campaign type has a different estimated NPV per "unit" of spend (e.g., per 1000 impressions or per click package), a cost per unit, and a maximum number of effective units the agency can purchase per day.
#
#     | Campaign Type      | Est. NPV per Unit | Cost per Unit | Max. Units per Day |
#     | ------------------ | -----------------: | -------------: | ------------------: |
#     | Social Media Ads   | \$2                | \$30           | 20                 |
#     | Search Engine Ads  | \$12               | \$25           | 15                 |
#     | Video Ads          | \$8                | \$40           | 10                 |
#     | Influencer Collabs | \$30               | \$100          | 6                  |
#
#     *   What combination of advertising units should Catalyst Marketing purchase each day to maximize the total estimated NPV within the $1,200 budget?
#
# ---

# %% [markdown]
# ### Question 3.6: Solution
#
# Profitability-index rule: Define $\quad \text{PI}=\frac{\text{NPV per unit}}{\text{Cost per unit}}$
#
# | Campaign | $\text{PI}$ | Max units | Cost if max | NPV if max |
# |----------|-----------:|---------:|-------------:|-----------:|
# | Search Engine Ads    | $0.48$ | 15 | \$375 | \$180 |
# | Influencer Collabs   | $0.30$ | 6  | \$600 | \$180 |
# | Video Ads            | $0.20$ | 10 | \$400 | \$80  |
# | Social Media Ads     | $0.07$ | 20 | \$600 | \$40  |
#
# Allocate the \$1 200 budget to the highest-PI campaign first:
#
# | Campaign | Units | Cost | NPV |
# |----------|------:|-----:|----:|
# | Search Engine Ads  | 15 | \$375 | \$180 |
# | Influencer Collabs | 6  | \$600 | \$180 |
# | Video Ads          | 5  | \$200 | \$40  |
# | Social Media Ads   | 0  | \$0   | \$0   |
# | **Total**          | —  | **\$1 175** | **\$400** |
#
# Overall PI of the chosen bundle: $\quad \frac{400}{1\,175}\approx0.34$
#
# ---

# %% [markdown]
# ## Capital Budgeting
#
# ---

# %% [markdown]
# ### Question 4.1
#
# TechNova Ltd. is evaluating the purchase of an automated workstation priced at $\$380,000$ with a useful life of 5 years. The system will be depreciated on a straight-line basis over five years, and its salvage value at the end of the period is expected to be $\$40,000$.
#
# By adopting this technology, the company will be able to eliminate three manual quality control position, saving a total of $135,000 per year in salaries.
#
# Additionally, the system will immediately reduce the company's required net working capital by $60,000. This NWC will need to be reinstated when the equipment is sold after 5 years.
#
# The firm's corporate tax rate is 25%, and the required rate of return is 11%.
#
# Should TechNova proceed with the investment?
#
# ---

# %% [markdown]
# ### Question 4.1: Solution
#
# Annual depreciation: $\quad D=\frac{380\,000}{5}=76\,000$
#
# Annual after-tax operating cash flow:
#
# $\quad \begin{aligned} \text{OCF}&=(135\,000-D)(1-0.25)+D =59\,000(0.75)+76\,000=120\,250 \end{aligned}$
#
# $CF_0=-380\,000+60\,000=-320\,000$
#
# $CF_{1-4}=120\,250$
#
# $CF_5=120\,250+40\,000(1-0.25)-60\,000=90\,250$
#
# $NPV=-320\,000+\sum_{t=1}^{4}\frac{120\,250}{1.11^{\,t}} +\frac{90\,250}{1.11^{\,5}} =106\,628.08 $
#
# The NPV is positive (\$106 628.08), so TechNova should proceed with the investment.
#
# ---

# %% [markdown]
# ### Question 4.2
#
# Evergreen Electronics is evaluating a new automated assembly line.
# * The equipment costs $\$4,500,000$ up front, and requires an immediate $\$200,000$ increase in net working capital.
# * Sales are expected to be \$2,600,000 per year for four years (after which the market will end). Operating costs are 30 % of sales.
# * The equipment will be straight‐line depreciated to zero over four years.
# * The corporate tax rate is 30 %, and the required return is 12 %.
# * Should Evergreen proceed wit the investment?
#
# ---

# %% [markdown]
# ### Question 4.2: Solution
#
# $CF_0 = -4\,500\,000 - 200\,000 = -4\,700\,000$
#
# **Annual cash flows ($t = 1 \text{ to } 4$)**
#   $$\begin{aligned}
#   \text{Sales} &= 2\,600\,000 \\
#   \text{Operating cost} &= 0.30 \times 2\,600\,000 = 780\,000 \\
#   \text{Depreciation} &= \frac{4\,500\,000}{4} = 1\,125\,000 \\
#   \text{EBIT} &= 2\,600\,000 - 780\,000 - 1\,125\,000 = 695\,000 \\
#   \text{Tax} &= 0.30 \times 695\,000 = 208\,500 \\
#   \text{Net income} &= 695\,000 - 208\,500 = 486\,500 \\
#   \text{OCF} &= 486\,500 + 1\,125\,000 = 1\,611\,500
#   \end{aligned}$$
#
# **Terminal‐year adjustment ($t = 4$):** $\quad \text{NWC recovery} = +200\,000 \quad\Longrightarrow\quad CF_4 = 1\,611\,500 + 200\,000 = 1\,811\,500$
#
# **NPV at $k = 12\%$:** $\quad \text{NPV} = -4\,700\,000 + 1\,611\,500 \!\left(\frac{1 - (1 + 0.12)^{-3}}{0.12}\right) + \frac{1\,811\,500}{(1 + 0.12)^{4}} \approx 321\,800 > 0$
#
# ---

# %% [markdown]
# ### Question 4.3
#
# PrintCo manufactures 120 000 printers per year (steady state).  Each printer needs one custom circuit board.  Currently they buy boards at $\$4.00$ each.  The plant manager proposes to produce boards in‑house at $\$2.50$ apiece.
#
# | Parameter                            | Value                  |
# |:-------------------------------------|:-----------------------|
# | Annual volume                        | 120 000 boards         |
# | Purchase price (outsourced)          | \$4.00 / board         |
# | In‑house variable cost               | \$2.50 / board         |
# | Capital cost of new machinery        | \$300 000              |
# | Economic life of machinery           | 5 years                |
# | Depreciation                         | Straight‑line to zero  |
# | Additional working capital (NWC)     | \$40 000 (recovered in Year 5) |
# | Salvage value at end of Year 5       | \$20 000               |
# | Tax rate                             | 25 %                   |
# | WACC                                 | 10 %                   |
#
# What is the net present value (NPV) of deciding to manufacture the circuit boards in‑house rather than buying them from the supplier?
#
# ---

# %% [markdown]
# ### Question 4.3: Solution
#
# - **Incremental savings per year**
#   $$\text{Savings}= (4.00-2.50)\times120\,000 = 180\,000$$
#
# - **Depreciation**
#   $$D=\frac{300\,000}{5}=60\,000$$
#
# - **Operating cash flow (Years 1–5)**
#   $$\text{OCF}=180\,000(1-0.25)+60\,000(0.25)=150\,000$$
#
# - **Initial outlay (Year 0)**
#   $$CF_0 = -300\,000 - 40\,000 = -340\,000$$
#
# - **Terminal extras (Year 5)**
#   $\text{After-tax salvage:} \quad 20\,000(1-0.25)=15\,000 \quad \text{and} \quad \text{NWC recovery:} \quad +40\,000 \quad \Rightarrow \quad \Delta CF_5 = 15\,000 + 40\,000 = 55\,000$
#
# - **Present value of annual OCFs:** $\quad PV_{\text{OCF}} = 150\,000\left(\frac{1-(1+0.10)^{-5}}{0.10}\right)=\$568\,622$
#
# - **Present value of terminal extras:** $\quad PV_{\text{term}} = \frac{55\,000}{(1+0.10)^5}= \$34\,151$
#
# - **NPV:** $\quad \text{NPV}=PV_{\text{OCF}}+PV_{\text{term}}+CF_0 = 568\,622+34\,151-340\,000 \approx \$262\,800>0$
#
# ---

# %% [markdown]
# ### Question 4.4
#
# Two recent engineering graduates, Alex and Ben, with limited start-up funds, decided to produce artisanal coffee makers. They estimate selling 7,000 units in the first year. Sales are projected to grow by 10 percent annually for the following five years.
#
# To begin operations, they will need an initial investment of $\$55,000$ in net working capital. Annual fixed costs are estimated at $\$95,000$, and variable production costs are $\$25$ per coffee maker. Each unit will be sold for $\$65$.
#
# The manufacturing equipment required will cost $220,000. This equipment will be depreciated using the straight-line method over its six-year useful life, with no expected salvage value at the end.
#
# The applicable corporate tax rate is 30 percent, and the project's required rate of return is 15 percent.
#
# Calculate the Net Present Value (NPV) of this venture.
#
# ---

# %% [markdown]
# ### Question 4.4: Solution
#
# Depreciation (straight-line): $\quad D=\frac{220\,000}{6}=36\,666.67$
#
# Units sold: $\quad q_1=7\,000,\; q_t=1.1\,q_{t-1}\;(t=2\ldots6)$
#
# Operating cash flow in year $t$: $\quad OCF_t=\Bigl[(65-25)q_t-95\,000-D\Bigr](1-0.30)+D$
#
# | $t$ | $q_t$ | $OCF_t$ ($) |
# |----:|-------:|-----------:|
# | 1 | 7 000.00 | 140 500.00 |
# | 2 | 7 700.00 | 160 100.00 |
# | 3 | 8 470.00 | 181 660.00 |
# | 4 | 9 317.00 | 205 376.00 |
# | 5 | 10 248.70 | 231 463.60 |
# | 6 | 11 273.57 | 260 159.96 |
#
# Initial outlay (year 0): $\quad CF_0=-220\,000-55\,000=-275\,000$
#
# Year-6 cash flow including NWC recovery: $\quad CF_6=260\,159.96+55\,000=315\,159.96$
#
# $$
# \begin{aligned}
# NPV&=-275\,000+\sum_{t=1}^{5}\frac{OCF_t}{1.15^{\,t}}+\frac{315\,159.96}{1.15^{\,6}}\\
# &=-275\,000+140\,500(0.8696)+160\,100(0.7562)\\
# &\quad+181\,660(0.6575)+205\,376(0.5718)+231\,463.60(0.4972)\\
# &\quad+315\,159.96(0.4323)\\
# &=456\,431.97
# \end{aligned}
# $$
#
# The NPV is \$456 431.97; since it is positive, Alex and Ben should undertake the venture.
#
# ---

# %% [markdown]
# ## Bond Valuation
#
# ---

# %% [markdown]
# ### Question 5.1
#
# BlueChip Systems has 7.5 percent coupon bonds outstanding with 12 years left until maturity. The bonds make semiannual payments and are currently priced at 98 percent of their face value. Calculate the current yield, the yield to maturity (YTM), and the effective annual yield (EAY) for these bonds.
#
# ---

# %% [markdown]
# ### Question 5.1: Solution
#
# Face value (assume)\$1 000
#
# Price 0.98 × 1 000 = \$980
#
# Coupon \$75 per year = \$37.50 every six months
#
# Periods to maturity 12 × 2 = 24
#
# Current yield: $\quad \text{CY} = \frac{75}{980} = 0.07653 \;\text{or}\; 7.65\%$
#
# Yield to maturity:
# $$980 = \frac{37.5}{r}\!\left[1-(1+r)^{-24}\right] + \frac{1\,000}{(1+r)^{24}} \quad \Rightarrow \quad r = 0.03880$$
#
# Nominal annual YTM: $\quad \text{YTM} = 2r = 0.07759 \;\text{or}\; 7.76\%$
#
# Effective annual yield: $\quad \text{EAY} = (1+r)^{2}-1 = (1.03880)^{2}-1 = 0.07910 \;\text{or}\; 7.91\%$
#
#
# ---

# %% [markdown]
# ### Question 5.2
#
# * The Yield to Maturity (YTM) represents the total return anticipated on a bond if the bond is held until it matures. However, if market interest rates fluctuate and you sell the bond prior to maturity, the actual return achieved is termed the Holding Period Yield (HPY).
#     * Imagine today you purchase an 8-year bond for $\$1,050$. This bond pays an annual coupon of 6.2 percent (assuming a face value of $\$1,000$). What is the initial YTM expected on this investment?
#     * Suppose that three years after your purchase, the prevailing YTM for similar bonds has risen by 0.75 percent. You decide to sell your bond at this point. What market price can you expect to receive for your bond? Calculate the annualized HPY for your investment over the three years. How does this HPY compare to the YTM calculated when you initially bought the bond, and what causes the difference?
#
# ---

# %% [markdown]
# ### Question 5.2: Solution
#
# $$1050=\sum_{t=1}^{8}\frac{62}{(1+r)^t}+\frac{1000}{(1+r)^8} \quad \Rightarrow \quad r=0.0541\;{\text{or}}\;5.41\%$$
#
# $\text{New yield} = 5.41\%+0.75\%=6.16\%$.
#
# Five years remain, so
#
# $$P_3=\sum_{t=1}^{5}\frac{62}{(1+0.0616)^t}+\frac{1000}{(1+0.0616)^5}=1001.53.$$
#
#
# **Annualised holding-period yield over the three years**
#
# $$1050=(1+h)^{-1}\!\cdot62+(1+h)^{-2}\!\cdot62+(1+h)^{-3}\!\cdot1063.53 \quad \Rightarrow \quad h=0.0443\;{\text{or}}\;4.43\%$$
#
# The HPY is lower because rising market yields reduced the bond’s price from \$1050 to \$1001.53, creating a capital loss that partially offset the coupon income.
#
# ---

# %% [markdown]
# ### Question 5.3
#
# Suppose there are four risk-free financial instruments available with the following market prices and guaranteed future payments:
#
# | Instrument | Current Price | Payment in Year 1 | Payment in Year 2 | Payment in Year 3 |
# |:------------:|---------------:|-------------------:|-------------------:|-------------------:|
# | X          | 950.00       | 1000              | 0                 | 0                 |
# | Y          | 890.00       | 0                 | 1000              | 0                 |
# | Z          | 985.00       | 50                | 50                | 1050              |
# | W          | 840.00       | 0                 | 0                 | 1000              |
#
# Based on this information, does an arbitrage opportunity exist?
# * If yes, describe the strategy to capture a risk-free profit.
# * If no, explain why the prices are consistent and preclude arbitrage.
#
# ---

# %% [markdown]
# ### Question 5.3: Solution
#
# Discount factors from the pure-payment instruments
#
# $$d_1=\frac{950.00}{1000}=0.95,\qquad
#   d_2=\frac{890.00}{1000}=0.89,\qquad
#   d_3=\frac{840.00}{1000}=0.84.$$
#
# Fair price of $Z$ implied by these discount factors
#
# $$
# P_Z^{\text{fair}}=50d_1+50d_2+1050d_3
#                  =50(0.95)+50(0.89)+1050(0.84)
#                  =47.50+44.50+882.00
#                  =974.00.
# $$
#
# Market price of $Z$ is \$985.00
#
# **Arbitrage strategy**
#
# | Action today | Units | Cash flow now | Year-1 | Year-2 | Year-3 |
# |--------------|------:|--------------:|-------:|-------:|-------:|
# | Sell overpriced $Z$ | $1$ | $+985.00$ | $-50$ | $-50$ | $-1050$ |
# | Buy $X$ | $0.05$ | $-47.50$ | $+50$ | $0$ | $0$ |
# | Buy $Y$ | $0.05$ | $-44.50$ | $0$ | $+50$ | $0$ |
# | Buy $W$ | $1.05$ | $-882.00$ | $0$ | $0$ | $+1050$ |
# | **Net** | | **+11.00** | $0$ | $0$ | $0$ |
#
# The portfolio costs \$974.00 but is funded with the \$985.00 received from short-selling $Z$, leaving an immediate risk-free gain of \$11.00 and zero net cash flows thereafter.
#
# ---

# %% [markdown]
# ### Question 5.4
#
# Apex Industries has issued zero-coupon corporate bonds with a seven-year maturity.
#
# - Investors estimate a 20% probability that Apex will default on these bonds.
#
# - If a default occurs, investors anticipate recovering only 50 cents per dollar of the face value.
#
# - If the required expected return for investing in these bonds is 7%, what would be the market price and the yield to maturity for these bonds?
#
# ---

# %% [markdown]
# ### Question 5.4: Solution
#
# Expected payoff at maturity: $\quad 0.8(1.0F)+0.2(0.5F)=0.90F$
#
# Required expected return: $7\% \quad \Rightarrow \quad P=\frac{0.90F}{(1+0.07)^{7}}=0.5605F$
#
# For $F = \$1\,000 \quad \Rightarrow \quad P = 0.5605 \times 1\,000 = \$560.47.$
#
# $$P=\frac{F}{(1+\text{YTM})^{7}} \quad\Longrightarrow\quad \text{YTM}=(1/P)^{1/7}-1 =(1/0.5605)^{1/7}-1 =0.0862 = 8.62\%$$
#
# ---

# %% [markdown]
# ### Question 5.5
#
# Redwood Enterprises leases sustainable forestry equipment in the Pacific Northwest. It has just issued a three-year, zero-coupon corporate bond at a price of $\$85$. You have purchased this bond and plan to hold it until it matures. Assume the face value is $\$100$.
#
# a. Calculate the yield to maturity (YTM) of this bond.
#
# b. What is the expected annual return on your investment if there is zero probability of default?
#
# c. What is your expected annual return if default is certain (100% probability), and you anticipate recovering 80% of the face value in bankruptcy?
#
# d. What is your expected annual return if the probability of default occurring before maturity is 40%, and if default occurs, you will recover 80% of the face value?
#
# e. Considering your answers for parts (b) through (d), comment on the relationship between the expected return and the three-year, risk-free interest rate in each scenario.
#
# ---

# %% [markdown]
# ### Question 5.5: Solution
#
# **Yield to maturity (YTM)**
#
# $$85=\frac{100}{(1+r)^{3}}\;\;\Longrightarrow\;\;r=\Bigl(\tfrac{100}{85}\Bigr)^{1/3}-1=5.57\%$$
#
# **Expected annual return if default probability = 0:** No default ⇒ cash flow = \$100, so
#
# $$\text{Return}=5.57\%\;(\text{same as YTM})$$
#
# **Expected annual return if default is certain with \$80 recovery**
#
# $$r=\Bigl(\tfrac{80}{85}\Bigr)^{1/3}-1=-2.00\%$$
#
# **Expected annual return if default probability = 40 %, recovery 80 %**
#
# Expected payoff at maturity: $\quad 0.60(100)+0.40(80)=92$
#
# $$r=\Bigl(\tfrac{92}{85}\Bigr)^{1/3}-1=2.67\%$$
#
# * With no default risk the expected return equals the 5.57 % YTM, which should exceed the risk-free rate (otherwise investors would arbitrage into Treasuries).
# * With a 40 % default probability the expected return falls to 2.67 %; this may be above or below the risk-free rate depending on market levels, but the risk premium is clearly smaller.
# * With certain default the expected return is –2.0 %, far below any positive risk-free rate.
#
# Thus, as default risk or expected loss severity rises, the bond’s expected return moves progressively farther below the risk-free benchmark.
#
# ---

# %% [markdown]
# ## Stock Valuation
#
# ---

# %% [markdown]
# ### Question 6.1
#
# AGE Corporation will pay an annual dividend of $\$1.10$ one year from now. Analysts expect this dividend to grow at 10% per year thereafter until the fourth year. After then, growth will level off at 3% per year indefinitely. According to the dividend-discount model, what is the value of a share of AGE Corp. stock if the firm's equity cost of capital ($r_{E}$) is 8%?
#
# ---

# %% [markdown]
# ### Question 6.1: Solution
#
# Dividends
# $$
# \begin{aligned}
# D_1 &= 1.10\\
# D_2 &= 1.10(1.10)=1.21\\
# D_3 &= 1.21(1.10)=1.331\\
# D_4 &= 1.331(1.10)=1.4641
# \end{aligned}
# $$
#
# Perpetual growth $3\%$ from year 5: $\quad D_5 = 1.4641(1.03)=1.508023$
#
# Terminal value at $t=4$: $\quad P_4 = \frac{D_5}{0.08-0.03}= \frac{1.508023}{0.05}=30.16046$
#
# $$
# \begin{aligned}
# P_0 &= \frac{1.10}{1.08}+\frac{1.21}{1.08^{2}}
#       +\frac{1.331}{1.08^{3}}+\frac{1.4641}{1.08^{4}}
#       +\frac{30.16046}{1.08^{4}}=26.36.
# \end{aligned}
# $$
#
# ---

# %% [markdown]
# ### Question 6.2
#
# AGE Corp intends to pay a total payout of $\$3.50$ per share to its shareholders next year. The company anticipates an earnings growth rate of 4.2% per year indefinitely, and its equity cost of capital ($r_E$) is 9.5%.
#
# * **Scenario 1: All Payouts as Dividends**
#
#     Assume AGE Corp pays the entire $\$3.50$ as a dividend ($D_1 = \$3.50$). If its dividend payout rate and expected growth rate remain constant, and AGE Corp does not issue or repurchase shares, estimate its share price ($P_0$).
#
# * **Scenario 2: Dividends and Repurchases**
#
#     Suppose AGE Corp decides to pay a dividend of $\$1.00$ per share ($D_1' = \$1.00$) this year and use the remaining $\$2.50$ per share ($\$3.50 - \$1.00$) to repurchase shares. If AGE Corp's total payout rate remains constant, estimate its share price.
#
# * **Growth Rates with Repurchases**
#
#     If AGE Corp maintains the payout split from Scenario 2 ($\$1.00$ dividend, $\$2.50$ repurchase per initial share) and the same total payout rate, at what rates are its dividends per share (DPS), earnings per share (EPS), and share price expected to grow?
#
# ---

# %% [markdown]
# ### Question 6.2: Solution
#
# **Scenario 1 – all cash as dividends**
#
# With $D_1=\$3.50$ and constant growth $g=4.2\%$,
#
# $$P_0=\frac{D_1}{r_E-g}= \frac{3.50}{0.095-0.042}\approx \$66.04.$$
#
# **Scenario 2 – \$1 dividend + \$2.50 repurchase**
#
# Total cash paid out next year is still \$3.50, so under the total-payout model
#
# $$P_0=\frac{\text{Total payout}_1}{r_E-g}= \frac{3.50}{0.095-0.042}\approx \$66.04.$$
#
# **Growth rates when the \$1 / \$2.50 split continues**
#
# * Repurchase yield: $\quad y_R=\frac{\$2.50}{P_0}\approx\frac{2.50}{66.04}=3.8\%$
#
# * Dividends per share (DPS): Each year DPS grows with earnings plus the effect of the shrinking share count.
#   $$g_{DPS}=g+y_R\;\approx\;4.2\%+3.8\% \;\approx\;8.0\%$$
#
# * Earnings per share (EPS) rises for the same two reasons, so
#   $$g_{EPS}=g_{DPS}\;\approx\;8.0\%.$$
#
# * Share price: With the total-payout ratio and $g$ unchanged, price appreciation equals the fundamental growth rate.
#   $$g_{P}=g=4.2\%.$$
#
# Since AGE’s total payout rate is fixed, every component of payout (dividends and buy-backs) rises with earnings at the same $g$ each year.
#
# Total dividends grow at $g$.  Because the share count shrinks at rate $y_R$, dividends per share grow at
#
# $$
# g_{\text{DPS}} \;=\; g + y_R
#                \;\approx\; 4.2\% + 3.8\%
#                \;=\; 8.0\%.
# $$
#
# Thus DPS (and EPS) rise 8 % per year, while the price itself appreciates at the underlying earnings growth rate 4.2 %.
#
# ---

# %% [markdown]
# ### Question 6.3
#
# Consider LAC Corp and FB Industries, both of which reported total earnings of $\$500,000$ this past year. Without undertaking any new projects, both firms are expected to continue generating earnings of $\$500,000$ per year in perpetuity. Assume that all earnings are paid out to shareholders as dividends and that investors require an equity return ($r_E$) of 12 percent for both firms.
#
# * What is the current Price-to-Earnings (P/E) ratio for each company?
# * LAC Corp has identified a new project expected to generate additional earnings of $\$80,000$ each year in perpetuity, starting next year. Calculate the new P/E ratio of the company based on this information.
# * FB Industries has a different new project expected to increase earnings by $\$150,000$ per year in perpetuity, starting next year. Calculate the new P/E ratio of this firm.
#
# ---

# %% [markdown]
# ### Question 6.3: Solution
#
# **Current (no new projects)**
#
# Annual earnings per share (EPS): $\quad E_0 = \$500{,}000$
#
# Perpetual value with no growth: $\quad P_0 = \frac{E_0}{r_E} = \frac{500{,}000}{0.12} = \$4{,}166{,}667$
#
# $$\text{Trailing P/E}_0 = \frac{P_0}{E_0} = \frac{1}{r_E} = \frac{1}{0.12} \approx 8.33$$
#
# *The forward P/E—price divided by next year’s earnings—is identical in this no-growth base case.*
#
# **LAC Corp adds a \$80 000 perpetual project**
#
# Next-year earnings jump to: $\quad E_1 = 500{,}000 + 80{,}000 = \$580{,}000 \quad \Rightarrow \quad P_{\text{LAC}} = \frac{E_1}{r_E} = \frac{580{,}000}{0.12} = \$4{,}833{,}333$
#
# | Ratio type | Numerator | Denominator | Value |
# |------------|-----------|-------------|-------|
# | **Trailing P/E** | $P_{\text{LAC}}$ | *last year’s* $E_0$ | $\dfrac{4{,}833{,}333}{500{,}000}=\dfrac{29}{3}\approx 9.67$ |
# | **Forward P/E**  | $P_{\text{LAC}}$ | *next year’s* $E_1$ | $\dfrac{4{,}833{,}333}{580{,}000}= \dfrac{1}{0.12}\approx 8.33$ |
#
# **FB Industries adds a \$150 000 perpetual project**
#
# Next-year earnings rise to: $\quad E_1 = 500{,}000 + 150{,}000 = \$650{,}000 \quad \Rightarrow \quad P_{\text{FB}} = \frac{650{,}000}{0.12} = \$5{,}416{,}667$
#
# | Ratio type | Numerator | Denominator | Value |
# |------------|-----------|-------------|-------|
# | **Trailing P/E** | $P_{\text{FB}}$ | $E_0$ | $\dfrac{5{,}416{,}667}{500{,}000}= \dfrac{65}{6}\approx 10.83$ |
# | **Forward P/E**  | $P_{\text{FB}}$ | $E_1$ | $\dfrac{5{,}416{,}667}{650{,}000}= \dfrac{1}{0.12}\approx 8.33$ |
#
# * Trailing P/E rises when a profitable perpetual project is announced, because the price jumps immediately while the denominator still reflects last year’s lower earnings.
#
# * Forward P/E stays constant at $\dfrac{1}{r_E}=8.33$ so long as earnings are level in perpetuity and fully paid out; the new project raises both price and next-year earnings proportionally.
#
# ---

# %% [markdown]
# ### Question 6.4
#
# DFB, Inc., expects earnings at the end of this year of $\$4.19$ per share, and it plans to pay a $\$2.43$ dividend at that time. DFB will retain $\$1.76$ per share of its earnings to reinvest in new projects with an expected return of 15.1% per year. Suppose DFB will maintain the same dividend payout rate, retention rate, and return on new investments in the future and will not change its number of outstanding shares. Assume a required rate of return of 12%.
#
# *   What growth rate of earnings would you forecast for DFB?
#
# *   Suppose DFB instead paid a dividend of $\$3.43$ per share at the end of this year and retained only $\$0.76$ per share in earnings. If DFB maintains this higher payout rate in the future, what stock price would you estimate now? Should DFB raise its dividend?
#
# * Should DFB raise its dividend?
#
# ---

# %% [markdown]
# ### Question 6.4: Solution
#
# **Forecasted growth with current payout**
#
# Retention ratio: $\quad b=\frac{1.76}{4.19}=0.420$
#
# $g=b\times\text{ROE}=0.420\times0.151=0.0634\;(\text{or }6.34\%\text{ per year})$
#
# **Share-price effect of raising the dividend**
#
# |                     | **Current policy** | **Higher dividend** |
# |---------------------|--------------------|---------------------|
# | Dividend next year  | $D_1=\$2.43$       | $D_1'=\$3.43$       |
# | Earnings retained   | $\$1.76$           | $\$0.76$            |
# | Retention ratio     | $b=0.420$          | $b'=0.181$          |
# | Growth rate         | $g=6.34\%$         | $g'=2.77\%$         |
# | Share price now     | $$P_0=\frac{2.43}{0.12-0.0634}= \$42.95$$ | $$P_0'=\frac{3.43}{0.12-0.0277}= \$37.15$$ |
#
# **Should DFB raise its dividend?**
# No.
#
# ---

# %% [markdown]
# ### Question 6.5
#
# Gamma Analytics, an all-equity financed firm, reported Earnings Per Share (EPS) of $\$5.00$ for the year 2024. The company plans a temporary reduction in payouts. It has just paid the 2024 dividend of $\$1.80$ per share. It plans to pay the same dividend amount for 2025. Starting in 2026, Gamma Analytics expects its growth opportunities to stabilize and will target a 40% dividend payout ratio and a 25% share repurchase ratio, resulting in a 65% total payout ratio. The firm expects its existing operations to continue generating the current level of EPS ($\$5.00$) indefinitely, with all future growth coming from new investments.
#
# Assume the return on new investments (RONI) is 12%, and Gamma Analytics' equity cost of capital ($r_E$) is 11%. Estimate Gamma Analytics' share price at the end of 2024 (immediately after the 2024 dividend has been paid).
#
# ---

# %% [markdown]
# ### Question 6.5: Solution
#
# **Earnings and cash flows for 2025**
#
# Retention in 2024 (available to invest during 2025): $\quad \text{Ret}_{24}=E_0-D_{24}=5.00-1.80 = \$3.20$
#
# Extra earnings created by those new investments: $\quad \Delta E = \text{Ret}_{24}\times\text{RONI}=3.20 \times 0.12 = \$0.384$
#
# Earnings at the end of 2025: $\quad E_{25}=E_0 + \Delta E = 5.00 + 0.384 = \$5.384$
#
# Cash paid to shareholders in 2025 (no buy-backs yet): $\quad D_{25} = \$1.80$
#
# **Permanent policy from 2026 onward**
#
# Total payout ratio from 2026: $0.40$ (dividends) $+ 0.25$ (buy-backs) $= 0.65$.
#
# The retention ratio going forward: $\quad b = 1 - 0.65 = 0.35$
#
# Long-run earnings growth: $\quad g = b \times \text{RONI} = 0.35 \times 0.12 = 0.042 = 4.2\%$
#
# Retention during 2025: $\quad \text{Ret}_{25} = E_{25} - D_{25} = 5.384 - 1.80 = \$3.584$
#
# Earnings at the end of 2026: $\quad E_{26} = E_{25} + 0.12 \times \text{Ret}_{25} = 5.384 + 0.430 = \$5.814$
#
# Total cash to shareholders in 2026: $\quad \pi_2 = 0.65 \times E_{26} = 0.65 \times 5.814 = \$3.779$
#
# Thereafter, both $E_t$ and $\pi_t$ grow at the constant rate $g = 4.2\%$ per year.
#
# **Share price at the end of 2024 (ex-dividend)**
#
# | Year | Cash flow |
# |------|-----------|
# | 2025 $(t=1)$ | $D_1 = 1.80$ |
# | 2026 $(t=2)$ | $D_2 = 3.779$ |
# | 2027 – $\infty$ | $D_2 (1+g)^{t-2}$ |
#
# $$
# \begin{aligned}
# P_0 &= \frac{D_1}{1+r_E} + \frac{D_2}{(1+r_E)^2} + \frac{\frac{D_2(1+g)}{r_E - g}}{(1+r_E)^2} \\
#     &= \frac{1.80}{1.11} + \frac{3.779}{(1.11)^2} + \frac{\frac{3.9377}{0.11 - 0.042}}{(1.11)^2} \\
#     &= 1.6216 + \frac{3.779}{1.2321} + \frac{57.9074}{1.2321} \approx \$51.69
# \end{aligned}
# $$
#
# ---
